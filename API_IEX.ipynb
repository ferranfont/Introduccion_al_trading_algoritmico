# %% [markdown]
# <a href="https://colab.research.google.com/github/ferranfont/Introduccion_al_trading_algoritmico/blob/main/API_IEX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib
import math
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
acciones = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sp_500_stocks.csv')

# %%
  seleccion = acciones['Ticker'].loc[344]
  seleccion
# Out:
# 'NUE'

# %%
acciones.head(20)
# Out:
#    Ticker
# 0       A
# 1     AAL
# 2     AAP
# 3    AAPL
# 4    ABBV
# 5     ABC
# 6    ABMD
# 7     ABT
# 8     ACN
# 9    ADBE
# 10    ADI
# 11    ADM
# 12    ADP
# 13   ADSK
# 14    AEE
# 15    AEP
# 16    AES
# 17    AFL
# 18    AIG
# 19    AIV

# %%
diccionario = {'eurusd':1.2344,'gbpusd':0.8854,'audusd':1.4532}
diccionario
# Out:
# {'audusd': 1.4532, 'eurusd': 1.2344, 'gbpusd': 0.8854}

# %%
diccionario['gbpusd']
# Out:
# 0.8854

# %%
symbol='MSC'
api_url = f'https://sandbox.iexapis.com/stable/stock/{symbol}/quote?token=Tpk_059b97af715d417d9f49f50b51b1c448'
data = requests.get(api_url).json()
data
# Out:
# {'avgTotalVolume': 6106,
#  'calculationPrice': 'close',
#  'change': 0.21,
#  'changePercent': 0.04525,
#  'close': 5.19,
#  'closeSource': 'fialcfoi',
#  'closeTime': 1662977816898,
#  'companyName': 'Studio City International Holdings Ltd - ADR',
#  'currency': 'USD',
#  'delayedPrice': 5.19,
#  'delayedPriceTime': 1648100805637,
#  'extendedChange': 0,
#  'extendedChangePercent': 0,
#  'extendedPrice': 5.15,
#  'extendedPriceTime': 1664676715639,
#  'high': 5.19,
#  'highSource': 'loesC',
#  'highTime': 1680303256207,
#  'iexAskPrice': None,
#  'iexAskSize': None,
#  'iexBidPrice': None,
#  'iexBidSize': None,
#  'iexClose': 5.06,
#  'iexCloseTime': 1672206726801,
#  'iexLastUpdated': None,
#  'iexMarketPercent': None,
#  'iexOpen': None,
#  'iexOpenTime': None,
#  'iexRealtimePrice': None,
#  'iexRealtimeSize': None,
#  'iexVolume': None,
#  'isUSMarketOpen': False,
#  'lastTradeTime': 1711316737142,
#  'latestPrice': 5.02,
#  'latestSource': 'Close',
#  'latestTime': 'February 25, 2022',
#  'latestUpdate': 1667077849027,
#  'latestVolume': 183,
#  'low': 4.98,
#  'lowSource': 'ineeueimtprd 1yda c5le ',
#  'lowTime': 1726382312695,
#  'marketCap': 469908060,
#  'oddLotDelayedPrice': 5.016,
#  'oddLotDelayedPriceTime': 1652216802693,
#  'open': 4.98,
#  'openSource': 'fificloa',
#  'openTime': 1689111594304,
#  'peRatio': None,
#  'previousClose': 4.83,
#  'previousVolume': 821,
#  'primaryExchange': 'NYIEEX.E N OTK  AOGWNSCKCRCH',
#  'symbol': 'MSC',
#  'volume': 181,
#  'week52High': 25.38,
#  'week52Low': 4.5,
#  'ytdChange': -0.02368384998559228}

# %%
ultimo_precio = data['latestPrice']
ultimo_precio
# Out:
# 5.02

# %%
ultimo_cierre = data['previousClose']
ultimo_cierre
# Out:
# 4.83

# %%
for i in range(0,502):
  seleccion = acciones['Ticker'].loc[i]
  print(seleccion)
# Out:
# A
# AAL
# AAP
# AAPL
# ABBV
# ABC
# ABMD
# ABT
# ACN
# ADBE
# ADI
# ADM
# ADP
# ADSK
# AEE
# AEP
# AES
# AFL
# AIG
# AIV
# AIZ
# AJG
# AKAM
# ALB
# ALGN
# ALK
# ALL
# ALLE
# ALXN
# AMAT
# AMCR
# AMD
# AME
# AMGN
# AMP
# AMT
# AMZN
# ANET
# ANSS
# ANTM
# AON
# AOS
# APA
# APD
# APH
# APTV
# ARE
# ATO
# ATVI
# AVB
# AVGO
# AVY
# AWK
# AXP
# AZO
# BA
# BAC
# BAX
# BBY
# BDX
# BEN
# BF.B
# BIIB
# BIO
# BK
# BKNG
# BKR
# BLK
# BLL
# BMY
# BR
# BRK.B
# BSX
# BWA
# BXP
# C
# CAG
# CAH
# CARR
# CAT
# CB
# CBOE
# CBRE
# CCI
# CCL
# CDNS
# CDW
# CE
# CERN
# CF
# CFG
# CHD
# CHRW
# CHTR
# CI
# CINF
# CL
# CLX
# CMA
# CMCSA
# CME
# CMG
# CMI
# CMS
# CNC
# CNP
# COF
# COG
# COO
# COP
# COST
# COTY
# CPB
# CPRT
# CRM
# CSCO
# CSX
# CTAS
# CTL
# CTSH
# CTVA
# CTXS
# CVS
# CVX
# CXO
# D
# DAL
# DD
# DE
# DFS
# DG
# DGX
# DHI
# DHR
# DIS
# DISCA
# DISCK
# DISH
# DLR
# DLTR
# DOV
# DOW
# DPZ
# DRE
# DRI
# DTE
# DUK
# DVA
# DVN
# DXC
# DXCM
# EA
# EBAY
# ECL
# ED
# EFX
# EIX
# EL
# EMN
# EMR
# EOG
# EQIX
# EQR
# ES
# ESS
# ETFC
# ETN
# ETR
# EVRG
# EW
# EXC
# EXPD
# EXPE
# EXR
# F
# FANG
# FAST
# FB
# FBHS
# FCX
# FDX
# FE
# FFIV
# FIS
# FISV
# FITB
# FLIR
# FLS
# FLT
# FMC
# FOX
# FOXA
# FRC
# FRT
# FTI
# FTNT
# FTV
# GD
# GE
# GILD
# GIS
# GL
# GLW
# GM
# GOOG
# GOOGL
# GPC
# GPN
# GPS
# GRMN
# GS
# GWW
# HAL
# HAS
# HBAN
# HBI
# HCA
# HD
# HES
# HFC
# HIG
# HII
# HLT
# HOLX
# HON
# HPE
# HPQ
# HRB
# HRL
# HSIC
# HST
# HSY
# HUM
# HWM
# IBM
# ICE
# IDXX
# IEX
# IFF
# ILMN
# INCY
# INFO
# INTC
# INTU
# IP
# IPG
# IPGP
# IQV
# IR
# IRM
# ISRG
# IT
# ITW
# IVZ
# J
# JBHT
# JCI
# JKHY
# JNJ
# JNPR
# JPM
# K
# KEY
# KEYS
# KHC
# KIM
# KLAC
# KMB
# KMI
# KMX
# KO
# KR
# KSS
# KSU
# L
# LB
# LDOS
# LEG
# LEN
# LH
# LHX
# LIN
# LKQ
# LLY
# LMT
# LNC
# LNT
# LOW
# LRCX
# LUV
# LVS
# LW
# LYB
# LYV
# MA
# MAA
# MAR
# MAS
# MCD
# MCHP
# MCK
# MCO
# MDLZ
# MDT
# MET
# MGM
# MHK
# MKC
# MKTX
# MLM
# MMC
# MMM
# MNST
# MO
# MOS
# MPC
# MRK
# MRO
# MS
# MSCI
# MSFT
# MSI
# MTB
# MTD
# MU
# MXIM
# MYL
# NBL
# NCLH
# NDAQ
# NEE
# NEM
# NFLX
# NI
# NKE
# NLOK
# NLSN
# NOC
# NOV
# NOW
# NRG
# NSC
# NTAP
# NTRS
# NUE
# NVDA
# NVR
# NWL
# NWS
# NWSA
# O
# ODFL
# OKE
# OMC
# ORCL
# ORLY
# OTIS
# OXY
# PAYC
# PAYX
# PBCT
# PCAR
# PEAK
# PEG
# PEP
# PFE
# PFG
# PG
# PGR
# PH
# PHM
# PKG
# PKI
# PLD
# PM
# PNC
# PNR
# PNW
# PPG
# PPL
# PRGO
# PRU
# PSA
# PSX
# PVH
# PWR
# PXD
# PYPL
# QCOM
# QRVO
# RCL
# RE
# REG
# REGN
# RF
# RHI
# RJF
# RL
# RMD
# ROK
# ROL
# ROP
# ROST
# RSG
# RTX
# SBAC
# SBUX
# SCHW
# SEE
# SHW
# SIVB
# SJM
# SLB
# SLG
# SNA
# SNPS
# SO
# SPG
# SPGI
# SRE
# STE
# STT
# STX
# STZ
# SWK
# SWKS
# SYF
# SYK
# SYY
# T
# TAP
# TDG
# TDY
# TEL
# TFC
# TFX
# TGT
# TIF
# TJX
# TMO
# TMUS
# TPR
# TROW
# TRV
# TSCO
# TSN
# TT
# TTWO
# TWTR
# TXN
# TXT
# TYL
# UA
# UAA
# UAL
# UDR
# UHS
# ULTA
# UNH
# UNM
# UNP
# UPS
# URI
# USB
# V
# VAR
# VFC
# VIAC
# VLO
# VMC
# VNO
# VRSK
# VRSN
# VRTX
# VTR
# VZ
# WAB
# WAT
# WBA
# WDC
# WEC
# WELL
# WFC
# WHR
# WLTW
# WM
# WMB
# WMT
# WRB
# WRK
# WST
# WU
# WY
# WYNN
# XEL
# XLNX
# XOM
# XRAY
# XRX
# XYL
# YUM
# ZBH

# %%
def subida(a,b):
  diferencial = ((b-a)/a)*100
  # redondeo_diferencial = round(diferencial,2)
  print ('La subida ha sido del:',round(diferencial,2),'%')

# %%
subida(ultimo_cierre,ultimo_precio)
# Out:
# La subida ha sido del: 3.93 %

# %%
for i in range (0,14):
  symbol = acciones['Ticker'].loc[i]
  #print(symbol)
  api_url = f'https://sandbox.iexapis.com/stable/stock/{symbol}/quote?token=Tpk_059b97af715d417d9f49f50b51b1c448'
  data = requests.get(api_url).json()
  ultimo_precio = data['latestPrice']
  description = data['companyName']
  print('El último precio de:', symbol,'-', description, ' ha sido: ', ultimo_precio,'$\n')
# Out:
# El último precio de: A - Agilent Technologies Inc.  ha sido:  137.16 $
#
# El último precio de: AAL - American Airlines Group Inc  ha sido:  17.54 $
#
# El último precio de: AAP - Advance Auto Parts Inc  ha sido:  207.66 $
#
# El último precio de: AAPL - Apple Inc  ha sido:  166.65 $
#
# El último precio de: ABBV - Abbvie Inc  ha sido:  156.06 $
#
# El último precio de: ABC - Amerisource Bergen Corp.  ha sido:  146.87 $
#
# El último precio de: ABMD - Abiomed Inc.  ha sido:  314.9 $
#
# El último precio de: ABT - Abbott Laboratories  ha sido:  126.11 $
#
# El último precio de: ACN - Accenture plc - Class A  ha sido:  330.87 $
#
# El último precio de: ADBE - Adobe Inc  ha sido:  475.08 $
#
# El último precio de: ADI - Analog Devices Inc.  ha sido:  165.95 $
#
# El último precio de: ADM - Archer Daniels Midland Co.  ha sido:  79.8 $
#
# El último precio de: ADP - Automatic Data Processing Inc.  ha sido:  210.42 $
#
# El último precio de: ADSK - Autodesk Inc.  ha sido:  226.98 $

# %%
for i in data:
  
  print(i)
# Out:
# avgTotalVolume
# calculationPrice
# change
# changePercent
# close
# closeSource
# closeTime
# companyName
# currency
# delayedPrice
# delayedPriceTime
# extendedChange
# extendedChangePercent
# extendedPrice
# extendedPriceTime
# high
# highSource
# highTime
# iexAskPrice
# iexAskSize
# iexBidPrice
# iexBidSize
# iexClose
# iexCloseTime
# iexLastUpdated
# iexMarketPercent
# iexOpen
# iexOpenTime
# iexRealtimePrice
# iexRealtimeSize
# iexVolume
# lastTradeTime
# latestPrice
# latestSource
# latestTime
# latestUpdate
# latestVolume
# low
# lowSource
# lowTime
# marketCap
# oddLotDelayedPrice
# oddLotDelayedPriceTime
# open
# openTime
# openSource
# peRatio
# previousClose
# previousVolume
# primaryExchange
# symbol
# volume
# week52High
# week52Low
# ytdChange
# isUSMarketOpen

# %%
seleccion = acciones['Ticker'].loc[4]
print(seleccion)
# Out:
# ABBV

# %%
  symbol = acciones['Ticker'].loc[36]
  print(symbol)
# Out:
# AMZN

# %% [markdown]
# Append alternativo en dataframe

# %%
# Creamos un DataFrame vacío el cuál lo rellenamos con filas nuevas con el método append. Finalmente filtramos las columnas que nos interesan.
final_dataframe = pd.DataFrame() 

for i in range (15):
  symbol = acciones['Ticker'].loc[i]
  api_url = f'https://sandbox.iexapis.com/stable/stock/{symbol}/quote?token=Tpk_059b97af715d417d9f49f50b51b1c448'
  data = requests.get(api_url).json()
  final_dataframe = final_dataframe.append([data])

final_dataframe[['symbol','companyName','iexClose']]
# Out:
#   symbol                     companyName  iexClose
# 0      A       Agilent Technologies Inc.    134.84
# 0    AAL     American Airlines Group Inc     17.92
# 0    AAP          Advance Auto Parts Inc    213.98
# 0   AAPL                       Apple Inc    172.25
# 0   ABBV                      Abbvie Inc    150.05
# 0    ABC        Amerisource Bergen Corp.    146.01
# 0   ABMD                    Abiomed Inc.    325.00
# 0    ABT             Abbott Laboratories    122.56
# 0    ACN         Accenture plc - Class A    335.25
# 0   ADBE                       Adobe Inc    486.50
# 0    ADI             Analog Devices Inc.    164.00
# 0    ADM      Archer Daniels Midland Co.     79.30
# 0    ADP  Automatic Data Processing Inc.    209.38
# 0   ADSK                   Autodesk Inc.    229.30
# 0    AEE                    Ameren Corp.     89.20
