# %% [markdown]
# <a href="https://colab.research.google.com/github/ferranfont/Introduccion_al_trading_algoritmico/blob/main/El_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# voy ahora a crear mi primer dataframe
mi_dataframe =[]
mi_dataframe
columnas =['open','high','Low','close','Volume','Dividends','splits' ]
mi_dataframe = pd.DataFrame(columns=columnas)
mi_dataframe
# Out:
# Empty DataFrame
# Columns: [open, high, Low, close, Volume, Dividends, splits]
# Index: []

# %%
mi_dataframe = yf.Ticker('BA')
df = mi_dataframe.history(start = '2021-01-05' ,end= '2022-01-10')
df
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2021-01-05  204.740005  213.350006  ...          0             0
# 2021-01-06  210.220001  215.610001  ...          0             0
# 2021-01-07  213.389999  216.600006  ...          0             0
# 2021-01-08  213.610001  214.100006  ...          0             0
# 2021-01-11  203.029999  207.779999  ...          0             0
# ...                ...         ...  ...        ...           ...
# 2022-01-03  204.000000  210.550003  ...          0             0
# 2022-01-04  211.300003  214.559998  ...          0             0
# 2022-01-05  216.639999  218.929993  ...          0             0
# 2022-01-06  214.639999  216.000000  ...          0             0
# 2022-01-07  212.979996  218.320007  ...          0             0
#
# [256 rows x 7 columns]

# %%
df.shape
# Out:
# (256, 7)

# %%
df.head(35)
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2021-01-05  204.740005  213.350006  ...          0             0
# 2021-01-06  210.220001  215.610001  ...          0             0
# 2021-01-07  213.389999  216.600006  ...          0             0
# 2021-01-08  213.610001  214.100006  ...          0             0
# 2021-01-11  203.029999  207.779999  ...          0             0
# 2021-01-12  206.649994  209.059998  ...          0             0
# 2021-01-13  207.149994  208.789993  ...          0             0
# 2021-01-14  208.789993  214.190002  ...          0             0
# 2021-01-15  208.960007  209.250000  ...          0             0
# 2021-01-19  206.990005  211.520004  ...          0             0
# 2021-01-20  213.240005  215.589996  ...          0             0
# 2021-01-21  211.720001  211.929993  ...          0             0
# 2021-01-22  205.550003  206.699997  ...          0             0
# ...

# %%
df['Medio']=0
df
# Out:
#                   Open        High         Low  ...  Dividends  Stock Splits  Medio
# Date                                            ...
# 2021-01-05  204.740005  213.350006  204.600006  ...          0             0      0
# 2021-01-06  210.220001  215.610001  209.339996  ...          0             0      0
# 2021-01-07  213.389999  216.600006  211.779999  ...          0             0      0
# 2021-01-08  213.610001  214.100006  208.160004  ...          0             0      0
# 2021-01-11  203.029999  207.779999  201.009995  ...          0             0      0
# ...                ...         ...         ...  ...        ...           ...    ...
# 2022-01-03  204.000000  210.550003  203.339996  ...          0             0      0
# 2022-01-04  211.300003  214.559998  209.779999  ...          0             0      0
# 2022-01-05  216.639999  218.929993  211.809998  ...          0             0      0
# 2022-01-06  214.639999  216.000000  207.860001  ...          0             0      0
# ...

# %%
filtro = df.sort_values('Volume', ascending=False)
filtro
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2021-03-12  253.860001  269.720001  ...          0             0
# 2021-03-15  274.149994  278.570007  ...          0             0
# 2021-02-24  212.100006  229.610001  ...          0             0
# 2021-03-03  226.360001  235.399994  ...          0             0
# 2021-03-11  248.770004  256.649994  ...          0             0
# ...                ...         ...  ...        ...           ...
# 2021-11-04  213.800003  214.820007  ...          0             0
# 2021-10-05  224.270004  226.449997  ...          0             0
# 2021-11-24  207.520004  211.220001  ...          0             0
# 2021-11-03  211.470001  213.759995  ...          0             0
# 2021-10-08  226.750000  228.710007  ...          0             0
#
# [256 rows x 7 columns]

# %%
round(df.loc['2021-11-03','Close'],2)
# Out:
# 213.38

# %%
df_filtrado = df[df['Volume']<5437600]
df_filtrado
df_filtrado.to_excel('filrado.xlsx')

# %%
for i in df.index:
  df.loc[i,'Close']=88
df
# Out:
#                   Open        High         Low  ...  Dividends  Stock Splits  Medio
# Date                                            ...
# 2021-01-05  204.740005  213.350006  204.600006  ...          0             0      0
# 2021-01-06  210.220001  215.610001  209.339996  ...          0             0      0
# 2021-01-07  213.389999  216.600006  211.779999  ...          0             0      0
# 2021-01-08  213.610001  214.100006  208.160004  ...          0             0      0
# 2021-01-11  203.029999  207.779999  201.009995  ...          0             0      0
# ...                ...         ...         ...  ...        ...           ...    ...
# 2022-01-03  204.000000  210.550003  203.339996  ...          0             0      0
# 2022-01-04  211.300003  214.559998  209.779999  ...          0             0      0
# 2022-01-05  216.639999  218.929993  211.809998  ...          0             0      0
# 2022-01-06  214.639999  216.000000  207.860001  ...          0             0      0
# ...

# %%
df[['Close','Volume']]
# Out:
#             Close    Volume
# Date
# 2021-01-05   33.0  19338300
# 2021-01-06   33.0  16202200
# 2021-01-07   33.0  14474100
# 2021-01-08   33.0  14144000
# 2021-01-11   33.0  16770300
# ...           ...       ...
# 2022-01-03   33.0   9060200
# 2022-01-04   33.0  11414600
# 2022-01-05   33.0  11564700
# 2022-01-06   33.0   7142200
# 2022-01-07   33.0   9518000
#
# [256 rows x 2 columns]

# %%
df
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 2021-01-05  204.740005  213.350006  ...          0             0
# 2021-01-06  210.220001  215.610001  ...          0             0
# 2021-01-07  213.389999  216.600006  ...          0             0
# 2021-01-08  213.610001  214.100006  ...          0             0
# 2021-01-11  203.029999  207.779999  ...          0             0
# ...                ...         ...  ...        ...           ...
# 2022-01-03  204.000000  210.550003  ...          0             0
# 2022-01-04  211.300003  214.559998  ...          0             0
# 2022-01-05  216.639999  218.929993  ...          0             0
# 2022-01-06  214.639999  216.000000  ...          0             0
# 2022-01-07  212.979996  218.320007  ...          0             0
#
# [256 rows x 7 columns]

# %%
acciones = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sp_500_stocks.csv')
acciones
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 500    YUM
# 501    ZBH
# 502   ZBRA
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %%
acciones.loc[425]
# Out:
# Ticker    SWKS
# Name: 425, dtype: object

# %%
for i in acciones['Ticker']:
  print(i)

# %%
adjetivo ='blanco'
caracteristica = f'mi perro es {adjetivo}'
print(caracteristica)
# Out:
# mi perro es blanco

# %%
df.to_excel('apple_en_formato_excell.xlsx')
